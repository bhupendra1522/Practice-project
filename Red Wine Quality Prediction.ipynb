# %%
import pandas as pd
import numpy as np

# %%
df=pd.read_csv("https://raw.githubusercontent.com/dsrscientist/DSData/master/winequality-red.csv")

# %%
df
# Out:
#       fixed acidity  volatile acidity  citric acid  residual sugar  chlorides  \
# 0               7.4             0.700         0.00             1.9      0.076
# 1               7.8             0.880         0.00             2.6      0.098
# 2               7.8             0.760         0.04             2.3      0.092
# 3              11.2             0.280         0.56             1.9      0.075
# 4               7.4             0.700         0.00             1.9      0.076
# ...             ...               ...          ...             ...        ...
# 1594            6.2             0.600         0.08             2.0      0.090
# 1595            5.9             0.550         0.10             2.2      0.062
# 1596            6.3             0.510         0.13             2.3      0.076
# 1597            5.9             0.645         0.12             2.0      0.075
# 1598            6.0             0.310         0.47             3.6      0.067
#
#       free sulfur dioxide  total sulfur dioxide  density    pH  sulphates  \
# 0                    11.0                  34.0  0.99780  3.51       0.56
# 1                    25.0                  67.0  0.99680  3.20       0.68
# 2                    15.0                  54.0  0.99700  3.26       0.65
# 3                    17.0                  60.0  0.99800  3.16       0.58
# 4                    11.0                  34.0  0.99780  3.51       0.56
# ...                   ...                   ...      ...   ...        ...
# 1594                 32.0                  44.0  0.99490  3.45       0.58
# 1595                 39.0                  51.0  0.99512  3.52       0.76
# 1596                 29.0                  40.0  0.99574  3.42       0.75
# 1597                 32.0                  44.0  0.99547  3.57       0.71
# 1598                 18.0                  42.0  0.99549  3.39       0.66
#
#       alcohol  quality
# 0         9.4        5
# 1         9.8        5
# 2         9.8        5
# 3         9.8        6
# 4         9.4        5
# ...       ...      ...
# 1594     10.5        5
# 1595     11.2        6
# 1596     11.0        6
# 1597     10.2        5
# 1598     11.0        6
#
# [1599 rows x 12 columns]

# %%
df.columns
# Out:
# Index(['fixed acidity', 'volatile acidity', 'citric acid', 'residual sugar',
#        'chlorides', 'free sulfur dioxide', 'total sulfur dioxide', 'density',
#        'pH', 'sulphates', 'alcohol', 'quality'],
#       dtype='object')

# %%
df.head(40)
# Out:
#     fixed acidity  volatile acidity  citric acid  residual sugar  chlorides  \
# 0             7.4             0.700         0.00             1.9      0.076
# 1             7.8             0.880         0.00             2.6      0.098
# 2             7.8             0.760         0.04             2.3      0.092
# 3            11.2             0.280         0.56             1.9      0.075
# 4             7.4             0.700         0.00             1.9      0.076
# 5             7.4             0.660         0.00             1.8      0.075
# 6             7.9             0.600         0.06             1.6      0.069
# 7             7.3             0.650         0.00             1.2      0.065
# 8             7.8             0.580         0.02             2.0      0.073
# 9             7.5             0.500         0.36             6.1      0.071
# 10            6.7             0.580         0.08             1.8      0.097
# 11            7.5             0.500         0.36             6.1      0.071
# 12            5.6             0.615         0.00             1.6      0.089
# 13            7.8             0.610         0.29             1.6      0.114
# 14            8.9             0.620         0.18             3.8      0.176
# 15            8.9             0.620         0.19             3.9      0.170
# 16            8.5             0.280         0.56             1.8      0.092
# 17            8.1             0.560         0.28             1.7      0.368
# 18            7.4             0.590         0.08             4.4      0.086
# 19            7.9             0.320         0.51             1.8      0.341
# 20            8.9             0.220         0.48             1.8      0.077
# 21            7.6             0.390         0.31             2.3      0.082
# 22            7.9             0.430         0.21             1.6      0.106
# 23            8.5             0.490         0.11             2.3      0.084
# 24            6.9             0.400         0.14             2.4      0.085
# 25            6.3             0.390         0.16             1.4      0.080
# 26            7.6             0.410         0.24             1.8      0.080
# 27            7.9             0.430         0.21             1.6      0.106
# 28            7.1             0.710         0.00             1.9      0.080
# 29            7.8             0.645         0.00             2.0      0.082
# 30            6.7             0.675         0.07             2.4      0.089
# 31            6.9             0.685         0.00             2.5      0.105
# 32            8.3             0.655         0.12             2.3      0.083
# 33            6.9             0.605         0.12            10.7      0.073
# 34            5.2             0.320         0.25             1.8      0.103
# 35            7.8             0.645         0.00             5.5      0.086
# 36            7.8             0.600         0.14             2.4      0.086
# 37            8.1             0.380         0.28             2.1      0.066
# 38            5.7             1.130         0.09             1.5      0.172
# 39            7.3             0.450         0.36             5.9      0.074
#
#     free sulfur dioxide  total sulfur dioxide  density    pH  sulphates  \
# 0                  11.0                  34.0   0.9978  3.51       0.56
# 1                  25.0                  67.0   0.9968  3.20       0.68
# 2                  15.0                  54.0   0.9970  3.26       0.65
# 3                  17.0                  60.0   0.9980  3.16       0.58
# 4                  11.0                  34.0   0.9978  3.51       0.56
# 5                  13.0                  40.0   0.9978  3.51       0.56
# 6                  15.0                  59.0   0.9964  3.30       0.46
# 7                  15.0                  21.0   0.9946  3.39       0.47
# 8                   9.0                  18.0   0.9968  3.36       0.57
# 9                  17.0                 102.0   0.9978  3.35       0.80
# 10                 15.0                  65.0   0.9959  3.28       0.54
# 11                 17.0                 102.0   0.9978  3.35       0.80
# 12                 16.0                  59.0   0.9943  3.58       0.52
# 13                  9.0                  29.0   0.9974  3.26       1.56
# 14                 52.0                 145.0   0.9986  3.16       0.88
# 15                 51.0                 148.0   0.9986  3.17       0.93
# 16                 35.0                 103.0   0.9969  3.30       0.75
# 17                 16.0                  56.0   0.9968  3.11       1.28
# 18                  6.0                  29.0   0.9974  3.38       0.50
# 19                 17.0                  56.0   0.9969  3.04       1.08
# 20                 29.0                  60.0   0.9968  3.39       0.53
# 21                 23.0                  71.0   0.9982  3.52       0.65
# 22                 10.0                  37.0   0.9966  3.17       0.91
# 23                  9.0                  67.0   0.9968  3.17       0.53
# 24                 21.0                  40.0   0.9968  3.43       0.63
# 25                 11.0                  23.0   0.9955  3.34       0.56
# 26                  4.0                  11.0   0.9962  3.28       0.59
# 27                 10.0                  37.0   0.9966  3.17       0.91
# 28                 14.0                  35.0   0.9972  3.47       0.55
# 29                  8.0                  16.0   0.9964  3.38       0.59
# 30                 17.0                  82.0   0.9958  3.35       0.54
# 31                 22.0                  37.0   0.9966  3.46       0.57
# 32                 15.0                 113.0   0.9966  3.17       0.66
# 33                 40.0                  83.0   0.9993  3.45       0.52
# 34                 13.0                  50.0   0.9957  3.38       0.55
# 35                  5.0                  18.0   0.9986  3.40       0.55
# 36                  3.0                  15.0   0.9975  3.42       0.60
# 37                 13.0                  30.0   0.9968  3.23       0.73
# 38                  7.0                  19.0   0.9940  3.50       0.48
# 39                 12.0                  87.0   0.9978  3.33       0.83
#
#     alcohol  quality
# 0       9.4        5
# 1       9.8        5
# 2       9.8        5
# 3       9.8        6
# 4       9.4        5
# 5       9.4        5
# 6       9.4        5
# 7      10.0        7
# 8       9.5        7
# 9      10.5        5
# 10      9.2        5
# 11     10.5        5
# 12      9.9        5
# 13      9.1        5
# 14      9.2        5
# 15      9.2        5
# 16     10.5        7
# 17      9.3        5
# 18      9.0        4
# 19      9.2        6
# 20      9.4        6
# 21      9.7        5
# 22      9.5        5
# 23      9.4        5
# 24      9.7        6
# 25      9.3        5
# 26      9.5        5
# 27      9.5        5
# 28      9.4        5
# 29      9.8        6
# 30     10.1        5
# 31     10.6        6
# 32      9.8        5
# 33      9.4        6
# 34      9.2        5
# 35      9.6        6
# 36     10.8        6
# 37      9.7        7
# 38      9.8        4
# 39     10.5        5

# %% [markdown]
# # Checking Null values in the dataframe.

# %%
# np.nan, None, NAN, others

# %%
df.isnull().sum()
# Out:
# fixed acidity           0
# volatile acidity        0
# citric acid             0
# residual sugar          0
# chlorides               0
# free sulfur dioxide     0
# total sulfur dioxide    0
# density                 0
# pH                      0
# sulphates               0
# alcohol                 0
# quality                 0
# dtype: int64

# %%
df.dtypes
# Out:
# fixed acidity           float64
# volatile acidity        float64
# citric acid             float64
# residual sugar          float64
# chlorides               float64
# free sulfur dioxide     float64
# total sulfur dioxide    float64
# density                 float64
# pH                      float64
# sulphates               float64
# alcohol                 float64
# quality                   int64
# dtype: object

# %%
df.shape[0]
# Out:
# 1599

# %%
df['fixed acidity'].unique()
# Out:
# array([ 7.4,  7.8, 11.2,  7.9,  7.3,  7.5,  6.7,  5.6,  8.9,  8.5,  8.1,
#         7.6,  6.9,  6.3,  7.1,  8.3,  5.2,  5.7,  8.8,  6.8,  4.6,  7.7,
#         8.7,  6.4,  6.6,  8.6, 10.2,  7. ,  7.2,  9.3,  8. ,  9.7,  6.2,
#         5. ,  4.7,  8.4, 10.1,  9.4,  9. ,  8.2,  6.1,  5.8,  9.2, 11.5,
#         5.4,  9.6, 12.8, 11. , 11.6, 12. , 15. , 10.8, 11.1, 10. , 12.5,
#        11.8, 10.9, 10.3, 11.4,  9.9, 10.4, 13.3, 10.6,  9.8, 13.4, 10.7,
#        11.9, 12.4, 12.2, 13.8,  9.1, 13.5, 10.5, 12.6, 14. , 13.7,  9.5,
#        12.7, 12.3, 15.6,  5.3, 11.3, 13. ,  6.5, 12.9, 14.3, 15.5, 11.7,
#        13.2, 15.9, 12.1,  5.1,  4.9,  5.9,  6. ,  5.5])

# %%
df['volatile acidity'].unique()
# Out:
# array([0.7  , 0.88 , 0.76 , 0.28 , 0.66 , 0.6  , 0.65 , 0.58 , 0.5  ,
#        0.615, 0.61 , 0.62 , 0.56 , 0.59 , 0.32 , 0.22 , 0.39 , 0.43 ,
#        0.49 , 0.4  , 0.41 , 0.71 , 0.645, 0.675, 0.685, 0.655, 0.605,
#        0.38 , 1.13 , 0.45 , 0.67 , 0.52 , 0.935, 0.29 , 0.31 , 0.51 ,
#        0.42 , 0.63 , 0.69 , 0.735, 0.725, 0.705, 0.785, 0.75 , 0.625,
#        0.3  , 0.55 , 1.02 , 0.775, 0.9  , 0.545, 0.575, 0.33 , 0.54 ,
#        1.07 , 0.695, 1.33 , 0.745, 1.04 , 0.715, 0.415, 0.34 , 0.68 ,
#        0.95 , 0.53 , 0.64 , 0.885, 0.805, 0.73 , 0.37 , 0.835, 1.09 ,
#        0.57 , 0.44 , 0.635, 0.82 , 0.48 , 1.   , 0.21 , 0.35 , 0.975,
#        0.26 , 0.87 , 0.18 , 0.27 , 0.2  , 0.36 , 0.83 , 0.46 , 0.47 ,
#        0.77 , 0.815, 0.795, 0.665, 0.765, 0.24 , 0.85 , 0.84 , 0.96 ,
#        0.78 , 0.23 , 0.315, 0.365, 0.25 , 0.825, 0.72 , 0.595, 0.585,
#        0.915, 0.755, 0.845, 1.24 , 0.8  , 0.98 , 1.185, 0.92 , 1.035,
#        1.025, 0.565, 0.74 , 1.115, 0.865, 0.875, 0.965, 0.91 , 0.89 ,
#        1.01 , 0.305, 0.395, 0.12 , 0.86 , 0.295, 1.005, 0.19 , 0.955,
#        0.16 , 1.58 , 0.79 , 1.18 , 0.475, 0.81 , 0.895, 0.855])

# %%
df['citric acid'].unique()
# Out:
# array([0.  , 0.04, 0.56, 0.06, 0.02, 0.36, 0.08, 0.29, 0.18, 0.19, 0.28,
#        0.51, 0.48, 0.31, 0.21, 0.11, 0.14, 0.16, 0.24, 0.07, 0.12, 0.25,
#        0.09, 0.3 , 0.2 , 0.22, 0.15, 0.43, 0.52, 0.23, 0.37, 0.26, 0.57,
#        0.4 , 0.49, 0.05, 0.54, 0.64, 0.7 , 0.47, 0.44, 0.17, 0.68, 0.53,
#        0.1 , 0.01, 0.55, 1.  , 0.03, 0.42, 0.33, 0.32, 0.35, 0.6 , 0.74,
#        0.58, 0.5 , 0.76, 0.46, 0.45, 0.38, 0.39, 0.66, 0.62, 0.67, 0.79,
#        0.63, 0.61, 0.71, 0.65, 0.59, 0.34, 0.69, 0.73, 0.72, 0.41, 0.27,
#        0.75, 0.13, 0.78])

# %%
df['residual sugar'].unique()
# Out:
# array([ 1.9 ,  2.6 ,  2.3 ,  1.8 ,  1.6 ,  1.2 ,  2.  ,  6.1 ,  3.8 ,
#         3.9 ,  1.7 ,  4.4 ,  2.4 ,  1.4 ,  2.5 , 10.7 ,  5.5 ,  2.1 ,
#         1.5 ,  5.9 ,  2.8 ,  2.2 ,  3.  ,  3.4 ,  5.1 ,  4.65,  1.3 ,
#         7.3 ,  7.2 ,  2.9 ,  2.7 ,  5.6 ,  3.1 ,  3.2 ,  3.3 ,  3.6 ,
#         4.  ,  7.  ,  6.4 ,  3.5 , 11.  ,  3.65,  4.5 ,  4.8 ,  2.95,
#         5.8 ,  6.2 ,  4.2 ,  7.9 ,  3.7 ,  6.7 ,  6.6 ,  2.15,  5.2 ,
#         2.55, 15.5 ,  4.1 ,  8.3 ,  6.55,  4.6 ,  4.3 ,  5.15,  6.3 ,
#         6.  ,  8.6 ,  7.5 ,  2.25,  4.25,  2.85,  3.45,  2.35,  2.65,
#         9.  ,  8.8 ,  5.  ,  1.65,  2.05,  0.9 ,  8.9 ,  8.1 ,  4.7 ,
#         1.75,  7.8 , 12.9 , 13.4 ,  5.4 , 15.4 ,  3.75, 13.8 ,  5.7 ,
#        13.9 ])

# %%
df['chlorides'].unique()
# Out:
# array([0.076, 0.098, 0.092, 0.075, 0.069, 0.065, 0.073, 0.071, 0.097,
#        0.089, 0.114, 0.176, 0.17 , 0.368, 0.086, 0.341, 0.077, 0.082,
#        0.106, 0.084, 0.085, 0.08 , 0.105, 0.083, 0.103, 0.066, 0.172,
#        0.074, 0.088, 0.332, 0.05 , 0.054, 0.113, 0.068, 0.081, 0.11 ,
#        0.07 , 0.111, 0.079, 0.115, 0.094, 0.093, 0.104, 0.464, 0.401,
#        0.062, 0.107, 0.045, 0.058, 0.102, 0.467, 0.091, 0.122, 0.09 ,
#        0.119, 0.178, 0.146, 0.072, 0.118, 0.049, 0.06 , 0.117, 0.087,
#        0.236, 0.61 , 0.095, 0.1  , 0.36 , 0.067, 0.27 , 0.099, 0.046,
#        0.061, 0.056, 0.039, 0.059, 0.101, 0.057, 0.337, 0.078, 0.263,
#        0.063, 0.611, 0.064, 0.096, 0.358, 0.343, 0.186, 0.112, 0.213,
#        0.214, 0.121, 0.128, 0.052, 0.12 , 0.116, 0.109, 0.159, 0.124,
#        0.174, 0.047, 0.127, 0.413, 0.152, 0.053, 0.055, 0.051, 0.125,
#        0.2  , 0.171, 0.226, 0.25 , 0.108, 0.148, 0.143, 0.222, 0.157,
#        0.422, 0.034, 0.387, 0.415, 0.243, 0.241, 0.19 , 0.132, 0.126,
#        0.038, 0.044, 0.041, 0.165, 0.048, 0.145, 0.147, 0.012, 0.194,
#        0.161, 0.123, 0.414, 0.216, 0.043, 0.042, 0.369, 0.166, 0.136,
#        0.403, 0.137, 0.168, 0.153, 0.267, 0.169, 0.205, 0.235, 0.23 ])

# %%
df['free sulfur dioxide'].unique()
# Out:
# array([11. , 25. , 15. , 17. , 13. ,  9. , 16. , 52. , 51. , 35. ,  6. ,
#        29. , 23. , 10. , 21. ,  4. , 14. ,  8. , 22. , 40. ,  5. ,  3. ,
#         7. , 12. , 30. , 33. , 50. , 19. , 20. , 27. , 18. , 28. , 34. ,
#        42. , 41. , 37. , 32. , 36. , 24. , 26. , 39. , 40.5, 68. , 31. ,
#        38. , 43. , 47. ,  1. , 54. , 46. , 45. ,  2. ,  5.5, 53. , 37.5,
#        57. , 48. , 72. , 55. , 66. ])

# %%
df['total sulfur dioxide'].unique()
# Out:
# array([ 34. ,  67. ,  54. ,  60. ,  40. ,  59. ,  21. ,  18. , 102. ,
#         65. ,  29. , 145. , 148. , 103. ,  56. ,  71. ,  37. ,  23. ,
#         11. ,  35. ,  16. ,  82. , 113. ,  83. ,  50. ,  15. ,  30. ,
#         19. ,  87. ,  46. ,  14. , 114. ,  12. ,  96. , 119. ,  73. ,
#         45. ,  10. , 110. ,  52. , 112. ,  39. ,  27. ,  94. ,  43. ,
#         42. ,  80. ,  51. ,  61. , 136. ,  31. , 125. ,  24. , 140. ,
#        133. ,  85. , 106. ,  22. ,  36. ,  69. ,  64. , 153. ,  47. ,
#        108. , 111. ,  62. ,  28. ,  89. ,  13. ,  90. , 134. ,  99. ,
#         26. ,  63. , 105. ,  20. , 141. ,  88. , 129. , 128. ,  86. ,
#        121. , 101. ,  44. ,   8. ,  49. ,  38. , 143. , 144. , 127. ,
#        126. , 120. ,  55. ,  93. ,  95. ,  41. ,  58. ,  72. ,  81. ,
#        109. ,  33. ,  53. ,  98. ,  48. ,  70. ,  25. , 135. ,  92. ,
#         74. ,  32. ,  77. , 165. ,  75. , 124. ,  78. , 122. ,  66. ,
#         68. ,  17. ,  91. ,  76. , 151. , 142. , 116. , 149. ,  57. ,
#        104. ,  84. , 147. , 155. , 152. ,   9. , 139. , 130. ,   7. ,
#        100. , 115. ,   6. ,  79. , 278. , 289. , 160. ,  77.5, 131. ])

# %%
df['density'].unique()
# Out:
# array([0.9978 , 0.9968 , 0.997  , 0.998  , 0.9964 , 0.9946 , 0.9959 ,
#        0.9943 , 0.9974 , 0.9986 , 0.9969 , 0.9982 , 0.9966 , 0.9955 ,
#        0.9962 , 0.9972 , 0.9958 , 0.9993 , 0.9957 , 0.9975 , 0.994  ,
#        0.9976 , 0.9934 , 0.9954 , 0.9971 , 0.9956 , 0.9983 , 0.9967 ,
#        0.9961 , 0.9984 , 0.9938 , 0.9932 , 0.9965 , 0.9963 , 0.996  ,
#        0.9973 , 0.9988 , 0.9937 , 0.9952 , 0.9916 , 0.9944 , 0.9996 ,
#        0.995  , 0.9981 , 0.9953 , 0.9924 , 0.9948 , 0.99695, 0.99545,
#        0.99615, 0.9994 , 0.99625, 0.99585, 0.99685, 0.99655, 0.99525,
#        0.99815, 0.99745, 0.9927 , 0.99675, 0.99925, 0.99565, 1.00005,
#        0.9985 , 0.99965, 0.99575, 0.9999 , 1.00025, 0.9987 , 0.99935,
#        0.99735, 0.99915, 0.9991 , 1.00015, 0.9997 , 1.001  , 0.9979 ,
#        1.0014 , 1.0001 , 0.99855, 0.99845, 0.9998 , 0.99645, 0.99865,
#        0.9989 , 0.99975, 0.999  , 1.0015 , 1.0002 , 0.9992 , 1.0008 ,
#        1.     , 1.0006 , 1.0004 , 1.0018 , 0.9912 , 1.0022 , 1.0003 ,
#        0.9949 , 0.9951 , 1.0032 , 0.9947 , 0.9995 , 0.9977 , 1.0026 ,
#        1.00315, 1.0021 , 0.9917 , 0.9922 , 0.9921 , 0.99788, 1.00024,
#        0.99768, 0.99782, 0.99761, 0.99803, 0.99785, 0.99656, 0.99488,
#        0.99823, 0.99779, 0.99738, 0.99701, 0.99888, 0.99938, 0.99744,
#        0.99668, 0.99727, 0.99586, 0.99612, 0.99676, 0.99732, 0.99814,
#        0.99746, 0.99708, 0.99818, 0.99639, 0.99531, 0.99786, 0.99526,
#        0.99641, 0.99264, 0.99682, 0.99356, 0.99386, 0.99702, 0.99693,
#        0.99562, 1.00012, 0.99462, 0.99939, 0.99632, 0.99976, 0.99606,
#        0.99154, 0.99624, 0.99417, 0.99376, 0.99832, 0.99836, 0.99694,
#        0.99064, 0.99672, 0.99647, 0.99736, 0.99629, 0.99689, 0.99801,
#        0.99652, 0.99538, 0.99594, 0.99686, 0.99438, 0.99357, 0.99628,
#        0.99748, 0.99578, 0.99371, 0.99522, 0.99576, 0.99552, 0.99664,
#        0.99614, 0.99517, 0.99787, 0.99533, 0.99536, 0.99824, 0.99577,
#        0.99491, 1.00289, 0.99743, 0.99774, 0.99444, 0.99892, 0.99528,
#        0.99331, 0.99901, 0.99674, 0.99512, 0.99395, 0.99504, 0.99516,
#        0.99604, 0.99468, 0.99543, 0.99791, 0.99425, 0.99509, 0.99484,
#        0.99834, 0.99864, 0.99498, 0.99566, 0.99408, 0.99458, 0.99648,
#        0.99568, 0.99613, 0.99519, 0.99518, 0.99592, 0.99654, 0.99546,
#        0.99554, 0.99733, 0.99669, 0.99724, 0.99643, 0.99605, 0.99658,
#        0.99416, 0.99712, 0.99418, 0.99596, 0.99556, 0.99918, 0.99697,
#        0.99378, 0.99162, 0.99495, 0.9928 , 0.99603, 0.99549, 0.99722,
#        0.99354, 0.99635, 0.99454, 0.99598, 0.99486, 0.99007, 0.99636,
#        0.99642, 0.99584, 0.99506, 0.99822, 0.99364, 0.99514, 0.99854,
#        0.99739, 0.99683, 0.99692, 0.99756, 0.99547, 0.99859, 0.99294,
#        0.99634, 0.99704, 0.99258, 0.99426, 0.99747, 0.99784, 0.99358,
#        0.99572, 0.99769, 0.99534, 0.99817, 0.99316, 0.99471, 0.99617,
#        0.99529, 0.99451, 0.99479, 0.99772, 0.99666, 0.99392, 0.99388,
#        0.99402, 0.9936 , 0.99374, 0.99523, 0.99593, 0.99396, 0.99698,
#        0.9902 , 0.99252, 0.99256, 0.99235, 0.99352, 0.99557, 0.99394,
#        0.9915 , 0.99379, 0.99798, 0.99341, 0.9933 , 0.99684, 0.99524,
#        0.99764, 0.99588, 0.99473, 0.99616, 0.99622, 0.99544, 0.99728,
#        0.99551, 0.99434, 0.99709, 0.99384, 0.99502, 0.99667, 0.99649,
#        0.99716, 0.99541, 0.99318, 0.99346, 0.99599, 0.99478, 0.99754,
#        0.99439, 0.99633, 0.99419, 0.99878, 0.99752, 0.99428, 0.99659,
#        0.99677, 0.99734, 0.99678, 0.99638, 0.99922, 0.99157, 0.99718,
#        0.99621, 0.99242, 0.99494, 0.99729, 0.99414, 0.99721, 0.99627,
#        0.99569, 0.99499, 0.99437, 0.99726, 0.99456, 0.99564, 0.9908 ,
#        0.99084, 0.9935 , 0.99385, 0.99688, 0.99619, 0.99476, 0.99328,
#        0.99286, 0.99914, 0.99521, 0.99362, 0.99558, 0.99323, 0.99191,
#        0.99501, 0.9929 , 0.99532, 0.99796, 0.99581, 0.99608, 0.99387,
#        0.99448, 0.99589, 0.99852, 0.99472, 0.99587, 0.99332, 0.99464,
#        0.99699, 0.99725, 0.99623, 0.99609, 0.99292, 0.9942 , 1.00369,
#        0.99713, 0.99322, 0.99706, 0.99974, 0.99467, 0.99236, 0.99705,
#        0.99334, 0.99336, 1.00242, 0.99182, 0.99808, 0.99828, 0.99719,
#        0.99542, 0.99496, 0.99344, 0.99348, 0.99459, 0.99492, 0.99508,
#        0.99582, 0.99555, 0.9941 , 0.99661, 0.99842, 0.99489, 0.99665,
#        0.99553, 0.99714, 0.99631, 0.99573, 0.99717, 0.99397, 0.99646,
#        0.99758, 0.99306, 0.99783, 0.99765, 0.99474, 0.99483, 0.99314,
#        0.99574, 0.99651])

# %%
df['pH'].unique()
# Out:
# array([3.51, 3.2 , 3.26, 3.16, 3.3 , 3.39, 3.36, 3.35, 3.28, 3.58, 3.17,
#        3.11, 3.38, 3.04, 3.52, 3.43, 3.34, 3.47, 3.46, 3.45, 3.4 , 3.42,
#        3.23, 3.5 , 3.33, 3.21, 3.48, 3.9 , 3.25, 3.32, 3.15, 3.41, 3.44,
#        3.31, 3.54, 3.13, 2.93, 3.14, 3.75, 3.85, 3.29, 3.08, 3.37, 3.19,
#        3.07, 3.49, 3.53, 3.24, 3.63, 3.22, 3.68, 2.74, 3.59, 3.  , 3.12,
#        3.57, 3.61, 3.06, 3.6 , 3.69, 3.1 , 3.05, 3.67, 3.27, 3.18, 3.02,
#        3.55, 2.99, 3.01, 3.56, 3.03, 3.62, 2.88, 2.95, 2.98, 3.09, 2.86,
#        3.74, 2.92, 3.72, 2.87, 2.89, 2.94, 3.66, 3.71, 3.78, 3.7 , 4.01,
#        2.9 ])

# %%
df['sulphates'].unique()
# Out:
# array([0.56, 0.68, 0.65, 0.58, 0.46, 0.47, 0.57, 0.8 , 0.54, 0.52, 1.56,
#        0.88, 0.93, 0.75, 1.28, 0.5 , 1.08, 0.53, 0.91, 0.63, 0.59, 0.55,
#        0.66, 0.6 , 0.73, 0.48, 0.83, 0.51, 0.9 , 1.2 , 0.74, 0.64, 0.77,
#        0.71, 0.62, 0.39, 0.79, 0.95, 0.82, 1.12, 1.14, 0.78, 1.95, 1.22,
#        1.98, 0.61, 1.31, 0.69, 0.67, 0.7 , 0.49, 0.92, 2.  , 0.72, 1.59,
#        0.33, 1.02, 0.97, 0.85, 0.43, 1.03, 0.86, 0.76, 1.61, 1.09, 0.84,
#        0.96, 0.45, 1.26, 0.87, 0.81, 1.  , 1.36, 1.18, 0.89, 0.98, 1.13,
#        1.04, 1.11, 0.99, 1.07, 0.44, 1.06, 1.05, 0.42, 1.17, 1.62, 0.94,
#        1.34, 1.16, 1.1 , 0.4 , 1.15, 0.37, 1.33, 1.01])

# %%
df['alcohol'].unique()
# Out:
# array([ 9.4       ,  9.8       , 10.        ,  9.5       , 10.5       ,
#         9.2       ,  9.9       ,  9.1       ,  9.3       ,  9.        ,
#         9.7       , 10.1       , 10.6       ,  9.6       , 10.8       ,
#        10.3       , 13.1       , 10.2       , 10.9       , 10.7       ,
#        12.9       , 10.4       , 13.        , 14.        , 11.5       ,
#        11.4       , 12.4       , 11.        , 12.2       , 12.8       ,
#        12.6       , 12.5       , 11.7       , 11.3       , 12.3       ,
#        12.        , 11.9       , 11.8       ,  8.7       , 13.3       ,
#        11.2       , 11.6       , 11.1       , 13.4       , 12.1       ,
#         8.4       , 12.7       , 14.9       , 13.2       , 13.6       ,
#        13.5       , 10.03333333,  9.55      ,  8.5       , 11.06666667,
#         9.56666667, 10.55      ,  8.8       , 13.56666667, 11.95      ,
#         9.95      ,  9.23333333,  9.25      ,  9.05      , 10.75      ])

# %%
df['quality'].unique()
# Out:
# array([5, 6, 7, 4, 8, 3], dtype=int64)

# %%
df.isnull().sum()
# Out:
# fixed acidity           0
# volatile acidity        0
# citric acid             0
# residual sugar          0
# chlorides               0
# free sulfur dioxide     0
# total sulfur dioxide    0
# density                 0
# pH                      0
# sulphates               0
# alcohol                 0
# quality                 0
# dtype: int64

# %%
df.dtypes
# Out:
# fixed acidity           float64
# volatile acidity        float64
# citric acid             float64
# residual sugar          float64
# chlorides               float64
# free sulfur dioxide     float64
# total sulfur dioxide    float64
# density                 float64
# pH                      float64
# sulphates               float64
# alcohol                 float64
# quality                   int64
# dtype: object

# %% [markdown]
# # Making DataFrame for the Nominal Data

# %%
df_visualization_nominal=df[['fixed acidity', 'volatile acidity', 'citric acid', 'residual sugar', 'chlorides', 'free sulfur dioxide',     
  'total sulfur dioxide' , 'density', 'pH', 'sulphates', 'alcohol', 'quality']].copy()

# %%
df_visualization_nominal.columns
# Out:
# Index(['fixed acidity', 'volatile acidity', 'citric acid', 'residual sugar',
#        'chlorides', 'free sulfur dioxide', 'total sulfur dioxide', 'density',
#        'pH', 'sulphates', 'alcohol', 'quality'],
#       dtype='object')

# %% [markdown]
# # Viuslizartion of the Data:

# %% [markdown]
# For the nominal categorical data we will use countplot as it will give the fequency of the columns

# %%
import seaborn as sns

# %%
ax = sns.countplot(x="fixed acidity",data=df_visualization_nominal)
print(df_visualization_nominal["fixed acidity"].value_counts())
# Out:
# 7.2     67
# 7.1     57
# 7.8     53
# 7.5     52
# 7.0     50
#         ..
# 13.5     1
# 13.8     1
# 13.4     1
# 4.7      1
# 5.5      1
# Name: fixed acidity, Length: 96, dtype: int64

# %%
ax = sns.countplot(x="volatile acidity",data=df_visualization_nominal)
print(df_visualization_nominal["volatile acidity"].value_counts())
# Out:
# 0.600    47
# 0.500    46
# 0.430    43
# 0.590    39
# 0.360    38
#          ..
# 1.035     1
# 0.565     1
# 1.130     1
# 1.115     1
# 1.090     1
# Name: volatile acidity, Length: 143, dtype: int64

# %%
ax = sns.countplot(x='citric acid', data=df_visualization_nominal)
print(df_visualization_nominal['citric acid'].value_counts())
# Out:
# 0.00    132
# 0.49     68
# 0.24     51
# 0.02     50
# 0.26     38
#        ...
# 0.72      1
# 0.62      1
# 0.75      1
# 1.00      1
# 0.78      1
# Name: citric acid, Length: 80, dtype: int64

# %%
ax = sns.countplot(x='citric acid', data=df_visualization_nominal)
print(df_visualization_nominal['citric acid'].value_counts())
# Out:
# 0.00    132
# 0.49     68
# 0.24     51
# 0.02     50
# 0.26     38
#        ...
# 0.72      1
# 0.62      1
# 0.75      1
# 1.00      1
# 0.78      1
# Name: citric acid, Length: 80, dtype: int64

# %%
ax = sns.countplot(x='residual sugar', data=df_visualization_nominal)
print(df_visualization_nominal['residual sugar'].value_counts())
# Out:
# 2.00     156
# 2.20     131
# 1.80     129
# 2.10     128
# 1.90     117
#         ...
# 4.25       1
# 2.85       1
# 3.45       1
# 2.35       1
# 13.90      1
# Name: residual sugar, Length: 91, dtype: int64

# %%
ax = sns.countplot(x='chlorides', data=df_visualization_nominal)
print(df_visualization_nominal['chlorides'].value_counts())
# Out:
# 0.080    66
# 0.074    55
# 0.076    51
# 0.078    51
# 0.084    49
#          ..
# 0.108     1
# 0.148     1
# 0.143     1
# 0.222     1
# 0.230     1
# Name: chlorides, Length: 153, dtype: int64

# %%
ax = sns.countplot(x='free sulfur dioxide', data=df_visualization_nominal)
print(df_visualization_nominal['free sulfur dioxide'].value_counts())
# Out:
# 6.0     138
# 5.0     104
# 10.0     79
# 15.0     78
# 12.0     75
# 7.0      71
# 9.0      62
# 16.0     61
# 17.0     60
# 11.0     59
# 13.0     57
# 8.0      56
# 14.0     50
# 3.0      49
# 18.0     46
# 4.0      41
# 21.0     41
# 19.0     39
# 24.0     34
# 26.0     32
# 23.0     32
# 20.0     30
# 27.0     29
# 25.0     24
# 29.0     23
# 28.0     23
# 22.0     22
# 32.0     22
# 31.0     20
# 34.0     18
# 30.0     16
# 35.0     15
# 36.0     11
# 33.0     11
# 38.0      9
# 41.0      7
# 40.0      6
# 39.0      5
# 48.0      4
# 51.0      4
# 45.0      3
# 1.0       3
# 43.0      3
# 42.0      3
# 52.0      3
# 37.0      3
# 68.0      2
# 55.0      2
# 50.0      2
# 37.5      2
# 53.0      1
# 72.0      1
# 57.0      1
# 47.0      1
# 5.5       1
# 2.0       1
# 46.0      1
# 54.0      1
# 40.5      1
# 66.0      1
# Name: free sulfur dioxide, dtype: int64

# %%
ax = sns.countplot(x='total sulfur dioxide', data=df_visualization_nominal)
print(df_visualization_nominal['total sulfur dioxide'].value_counts())
# Out:
# 28.0     43
# 24.0     36
# 15.0     35
# 18.0     35
# 23.0     34
#          ..
# 139.0     1
# 149.0     1
# 152.0     1
# 155.0     1
# 165.0     1
# Name: total sulfur dioxide, Length: 144, dtype: int64

# %%
ax = sns.countplot(x='density', data=df_visualization_nominal)
print(df_visualization_nominal['density'].value_counts())
# Out:
# 0.99720    36
# 0.99680    35
# 0.99760    35
# 0.99800    29
# 0.99620    28
#            ..
# 0.99684     1
# 0.99764     1
# 0.99473     1
# 0.99320     1
# 0.99651     1
# Name: density, Length: 436, dtype: int64

# %%
ax = sns.countplot(x='pH', data=df_visualization_nominal)
print(df_visualization_nominal['pH'].value_counts())
# Out:
# 3.30    57
# 3.36    56
# 3.26    53
# 3.38    48
# 3.39    48
#         ..
# 3.75     1
# 2.74     1
# 3.70     1
# 3.85     1
# 2.90     1
# Name: pH, Length: 89, dtype: int64

# %% [markdown]
# # Making dataframe of the ordinal data.

# %%
Df_visualiization_ordinal=df[["volatile acidity","fixed acidity"]].copy

# %%
sns.catplot(x="volatile acidity", y="fixed acidity", data=df)

# %% [markdown]
# # Checking the distribution of the continuous value of the flot type columns.

# %%
df_visualization_continuous=df[["alcohol","quality"]].copy()

# %%
import seaborn as sns
sns.displot(df_visualization_continuous['alcohol'], kde=True)

# %%
sns.displot(df_visualization_continuous['quality'], kde=True)

# %% [markdown]
# # Encoding of DataFrame:

# %%
from sklearn.preprocessing import OrdinalEncoder
enc=OrdinalEncoder()

# %%
for i in df.columns:
    if df[i].dtypes=="object":
        df[i]=enc.fit_transform(df[i].values.reshape(-1,1))

# %%
df
# Out:
#       fixed acidity  volatile acidity  citric acid  residual sugar  chlorides  \
# 0               7.4             0.700         0.00             1.9      0.076
# 1               7.8             0.880         0.00             2.6      0.098
# 2               7.8             0.760         0.04             2.3      0.092
# 3              11.2             0.280         0.56             1.9      0.075
# 4               7.4             0.700         0.00             1.9      0.076
# ...             ...               ...          ...             ...        ...
# 1594            6.2             0.600         0.08             2.0      0.090
# 1595            5.9             0.550         0.10             2.2      0.062
# 1596            6.3             0.510         0.13             2.3      0.076
# 1597            5.9             0.645         0.12             2.0      0.075
# 1598            6.0             0.310         0.47             3.6      0.067
#
#       free sulfur dioxide  total sulfur dioxide  density    pH  sulphates  \
# 0                    11.0                  34.0  0.99780  3.51       0.56
# 1                    25.0                  67.0  0.99680  3.20       0.68
# 2                    15.0                  54.0  0.99700  3.26       0.65
# 3                    17.0                  60.0  0.99800  3.16       0.58
# 4                    11.0                  34.0  0.99780  3.51       0.56
# ...                   ...                   ...      ...   ...        ...
# 1594                 32.0                  44.0  0.99490  3.45       0.58
# 1595                 39.0                  51.0  0.99512  3.52       0.76
# 1596                 29.0                  40.0  0.99574  3.42       0.75
# 1597                 32.0                  44.0  0.99547  3.57       0.71
# 1598                 18.0                  42.0  0.99549  3.39       0.66
#
#       alcohol  quality
# 0         9.4        5
# 1         9.8        5
# 2         9.8        5
# 3         9.8        6
# 4         9.4        5
# ...       ...      ...
# 1594     10.5        5
# 1595     11.2        6
# 1596     11.0        6
# 1597     10.2        5
# 1598     11.0        6
#
# [1599 rows x 12 columns]

# %% [markdown]
# # discribe the dataset:

# %%
# only continuous columns
df.describe()
# Out:
#        fixed acidity  volatile acidity  citric acid  residual sugar  \
# count    1599.000000       1599.000000  1599.000000     1599.000000
# mean        8.319637          0.527821     0.270976        2.538806
# std         1.741096          0.179060     0.194801        1.409928
# min         4.600000          0.120000     0.000000        0.900000
# 25%         7.100000          0.390000     0.090000        1.900000
# 50%         7.900000          0.520000     0.260000        2.200000
# 75%         9.200000          0.640000     0.420000        2.600000
# max        15.900000          1.580000     1.000000       15.500000
#
#          chlorides  free sulfur dioxide  total sulfur dioxide      density  \
# count  1599.000000          1599.000000           1599.000000  1599.000000
# mean      0.087467            15.874922             46.467792     0.996747
# std       0.047065            10.460157             32.895324     0.001887
# min       0.012000             1.000000              6.000000     0.990070
# 25%       0.070000             7.000000             22.000000     0.995600
# 50%       0.079000            14.000000             38.000000     0.996750
# 75%       0.090000            21.000000             62.000000     0.997835
# max       0.611000            72.000000            289.000000     1.003690
#
#                 pH    sulphates      alcohol      quality
# count  1599.000000  1599.000000  1599.000000  1599.000000
# mean      3.311113     0.658149    10.422983     5.636023
# std       0.154386     0.169507     1.065668     0.807569
# min       2.740000     0.330000     8.400000     3.000000
# 25%       3.210000     0.550000     9.500000     5.000000
# 50%       3.310000     0.620000    10.200000     6.000000
# 75%       3.400000     0.730000    11.100000     6.000000
# max       4.010000     2.000000    14.900000     8.000000

# %%
import matplotlib.pyplot as plt
plt.figure(figsize=(22,7))
sns.heatmap(df.describe(),annot=True,linewidths=0.1,linecolor="black",fmt="0.2f")
# Out:
# <AxesSubplot:>

# %% [markdown]
# # Correlation of the columns with the target columns:

# %%
df.corr()['fixed acidity'].sort_values()
# Out:
# pH                     -0.682978
# volatile acidity       -0.256131
# free sulfur dioxide    -0.153794
# total sulfur dioxide   -0.113181
# alcohol                -0.061668
# chlorides               0.093705
# residual sugar          0.114777
# quality                 0.124052
# sulphates               0.183006
# density                 0.668047
# citric acid             0.671703
# fixed acidity           1.000000
# Name: fixed acidity, dtype: float64

# %%
plt.figure(figsize=(22,7))
sns.heatmap(df.corr(),annot=True,linewidths=0.1,linecolor="black",fmt="0.2f",)
# Out:
# <AxesSubplot:>

# %% [markdown]
# # cheking the colunms which are poositively and negative correlated with the target columns:

# %%
plt.figure(figsize=(22,7))
df.corr()['fixed acidity'].sort_values(ascending=False).drop(['fixed acidity']).plot(kind='bar',color='c')
plt.xlabel('Feature',fontsize=14)
plt.ylabel('column with target names',fontsize=14)
plt.title('correlation',fontsize=18)
plt.show()

# %%
df.skew()
# Out:
# fixed acidity           0.982751
# volatile acidity        0.671593
# citric acid             0.318337
# residual sugar          4.540655
# chlorides               5.680347
# free sulfur dioxide     1.250567
# total sulfur dioxide    1.515531
# density                 0.071288
# pH                      0.193683
# sulphates               2.428672
# alcohol                 0.860829
# quality                 0.217802
# dtype: float64

# %% [markdown]
# # outliers Check:

# %%
df.dtypes
# Out:
# fixed acidity           float64
# volatile acidity        float64
# citric acid             float64
# residual sugar          float64
# chlorides               float64
# free sulfur dioxide     float64
# total sulfur dioxide    float64
# density                 float64
# pH                      float64
# sulphates               float64
# alcohol                 float64
# quality                   int64
# dtype: object

# %%
df['fixed acidity'].plot.box()
# Out:
# <AxesSubplot:>

# %%
df['volatile acidity'].plot.box()
# Out:
# <AxesSubplot:>

# %%
df['citric acid'].plot.box()
# Out:
# <AxesSubplot:>

# %%
df['residual sugar'].plot.box()
# Out:
# <AxesSubplot:>

# %%
df['alcohol'].plot.box()
# Out:
# <AxesSubplot:>

# %%
df['quality'].plot.box()
# Out:
# <AxesSubplot:>

# %% [markdown]
# # Considering the Outlier removel

# %%
df.shape
# Out:
# (1599, 12)

# %%
from scipy.stats import zscore
import numpy as np
z=np.abs(zscore(df))
threshold=3
np.where(z>3)
# Out:
# (array([  13,   14,   15,   15,   17,   17,   19,   33,   38,   42,   43,
#           45,   57,   81,   81,   83,   86,   88,   91,   92,   95,  106,
#          106,  109,  120,  126,  127,  142,  144,  147,  151,  151,  151,
#          151,  163,  164,  169,  169,  181,  199,  226,  226,  240,  243,
#          244,  258,  258,  274,  281,  291,  324,  325,  339,  340,  347,
#          354,  374,  381,  391,  396,  396,  400,  400,  442,  442,  451,
#          459,  467,  480,  480,  494,  515,  517,  544,  554,  554,  555,
#          555,  557,  557,  568,  584,  588,  591,  595,  608,  614,  636,
#          639,  649,  649,  651,  652,  652,  652,  672,  672,  684,  690,
#          690,  692,  692,  695,  723,  724,  730,  754,  776,  777,  795,
#          821,  832,  836,  837,  889,  899,  911,  917,  923,  925,  926,
#          982, 1017, 1018, 1043, 1051, 1051, 1071, 1074, 1079, 1079, 1081,
#         1081, 1111, 1114, 1131, 1154, 1165, 1175, 1186, 1231, 1235, 1244,
#         1244, 1244, 1260, 1269, 1269, 1270, 1270, 1288, 1289, 1295, 1296,
#         1299, 1299, 1300, 1312, 1316, 1319, 1319, 1321, 1358, 1367, 1370,
#         1370, 1372, 1372, 1374, 1374, 1434, 1434, 1434, 1435, 1435, 1435,
#         1469, 1474, 1474, 1474, 1476, 1476, 1476, 1478, 1493, 1496, 1505,
#         1558, 1558, 1570, 1574, 1589], dtype=int64),
#  array([ 9,  5,  5,  6,  4,  9,  4,  3,  1,  4,  9,  8,  5,  4,  9,  4,  9,
#          9,  9,  9,  8,  4,  9,  6,  1,  1,  1, 10, 10,  4,  2,  4,  8,  9,
#          3,  3,  4,  9,  4,  1,  4,  9,  4,  0,  0,  4,  9,  3,  4,  4,  3,
#          3,  9,  9,  0,  6,  0,  0,  0,  3,  5,  3,  5,  0,  7,  4, 11, 10,
#          3,  7,  3,  6, 11,  0,  0,  7,  0,  7,  0,  7,  4,  5, 10,  6,  3,
#          7,  9,  6,  9,  3,  6,  6,  0,  3, 10,  1,  6,  6,  1, 11,  4,  9,
#          8,  9,  1,  4,  4,  4,  4,  9, 10, 11,  7,  7,  7, 11,  3,  3,  3,
#          5,  5,  5,  7,  7,  3,  4,  9,  3,  3,  3,  6,  3,  6,  8,  7,  5,
#          5,  4,  5,  3,  5,  3,  3,  5,  6,  4,  7, 10,  7, 10,  9,  9,  5,
#          5,  1, 11,  8,  1,  8,  4,  9,  8,  5,  9,  4,  9,  4,  9,  4, 11,
#          3,  5,  7,  3,  5,  7, 11,  3,  5,  7,  3,  5,  7, 11,  6,  6, 11,
#          4,  5,  4,  3,  3], dtype=int64))

# %%
df_new_z=df[(z<3).all(axis=1)]
df_new_z
# Out:
#       fixed acidity  volatile acidity  citric acid  residual sugar  chlorides  \
# 0               7.4             0.700         0.00             1.9      0.076
# 1               7.8             0.880         0.00             2.6      0.098
# 2               7.8             0.760         0.04             2.3      0.092
# 3              11.2             0.280         0.56             1.9      0.075
# 4               7.4             0.700         0.00             1.9      0.076
# ...             ...               ...          ...             ...        ...
# 1594            6.2             0.600         0.08             2.0      0.090
# 1595            5.9             0.550         0.10             2.2      0.062
# 1596            6.3             0.510         0.13             2.3      0.076
# 1597            5.9             0.645         0.12             2.0      0.075
# 1598            6.0             0.310         0.47             3.6      0.067
#
#       free sulfur dioxide  total sulfur dioxide  density    pH  sulphates  \
# 0                    11.0                  34.0  0.99780  3.51       0.56
# 1                    25.0                  67.0  0.99680  3.20       0.68
# 2                    15.0                  54.0  0.99700  3.26       0.65
# 3                    17.0                  60.0  0.99800  3.16       0.58
# 4                    11.0                  34.0  0.99780  3.51       0.56
# ...                   ...                   ...      ...   ...        ...
# 1594                 32.0                  44.0  0.99490  3.45       0.58
# 1595                 39.0                  51.0  0.99512  3.52       0.76
# 1596                 29.0                  40.0  0.99574  3.42       0.75
# 1597                 32.0                  44.0  0.99547  3.57       0.71
# 1598                 18.0                  42.0  0.99549  3.39       0.66
#
#       alcohol  quality
# 0         9.4        5
# 1         9.8        5
# 2         9.8        5
# 3         9.8        6
# 4         9.4        5
# ...       ...      ...
# 1594     10.5        5
# 1595     11.2        6
# 1596     11.0        6
# 1597     10.2        5
# 1598     11.0        6
#
# [1451 rows x 12 columns]

# %%
df_new_z.shape
# Out:
# (1451, 12)

# %%
Data_loss=((1599-1451)/1599)*100

# %%
Data_loss
# Out:
# 9.255784865540964

# %% [markdown]
# # Separating the columns into features and target:

# %%
features=df.drop("quality",axis=1)
target=df["quality"]

# %%
from sklearn.preprocessing import MinMaxScaler
mms=MinMaxScaler()
from sklearn.linear_model import LinearRegression
lr=LinearRegression()
from sklearn.metrics import r2_score
from sklearn.model_selection import train_test_split

# %%
import warnings
warnings.filterwarnings('ignore')

# %%
for i in range(0,100):
    features_train,features_test,target_train,target_test=train_test_split(features,target,test_size=0.2,random_state=i)
    lr.fit(features_train,target_train)
    pred_train=lr.predict(features_train)
    pred_test=lr.predict(features_test)
    print(f"At random state {i},the training accuracy is:- {r2_score(target_train,pred_train)}")
    print(f"At random state {i},the testing accuracy is:- {r2_score(target_test,pred_test)}")
    print("\n")
# Out:
# At random state 0,the training accuracy is:- 0.3654519616206868
# At random state 0,the testing accuracy is:- 0.3283887639580213
#
#
# At random state 1,the training accuracy is:- 0.36558499214790463
# At random state 1,the testing accuracy is:- 0.3266402726986818
#
#
# At random state 2,the training accuracy is:- 0.37079770098666665
# At random state 2,the testing accuracy is:- 0.3024388697391551
#
#
# At random state 3,the training accuracy is:- 0.3530297271672964
# At random state 3,the testing accuracy is:- 0.3869039632632535
#
#
# At random state 4,the training accuracy is:- 0.36362946599677415
# At random state 4,the testing accuracy is:- 0.3369500251369858
#
#
# At random state 5,the training accuracy is:- 0.3536087659821445
# At random state 5,the testing accuracy is:- 0.37874687431635123
#
#
# At random state 6,the training accuracy is:- 0.3517392094319982
# At random state 6,the testing accuracy is:- 0.3894742190108451
#
#
# At random state 7,the training accuracy is:- 0.359974919089322
# At random state 7,the testing accuracy is:- 0.3468858137200873
#
#
# At random state 8,the training accuracy is:- 0.3578919148115478
# At random state 8,the testing accuracy is:- 0.3588548729210791
#
#
# At random state 9,the training accuracy is:- 0.36727428588960365
# At random state 9,the testing accuracy is:- 0.31442051423899153
#
#
# At random state 10,the training accuracy is:- 0.353276859432188
# At random state 10,the testing accuracy is:- 0.370757657416552
#
#
# At random state 11,the training accuracy is:- 0.36142429747216853
# At random state 11,the testing accuracy is:- 0.3385879347649635
#
#
# At random state 12,the training accuracy is:- 0.3668160062722696
# At random state 12,the testing accuracy is:- 0.31936958308068886
#
#
# At random state 13,the training accuracy is:- 0.36115280147112483
# At random state 13,the testing accuracy is:- 0.35395945169177134
#
#
# At random state 14,the training accuracy is:- 0.36632487563066585
# At random state 14,the testing accuracy is:- 0.3243508918082777
#
#
# At random state 15,the training accuracy is:- 0.3689700137486426
# At random state 15,the testing accuracy is:- 0.320827822245911
#
#
# At random state 16,the training accuracy is:- 0.374969777072357
# At random state 16,the testing accuracy is:- 0.27248095002260364
#
#
# At random state 17,the training accuracy is:- 0.344406332857357
# At random state 17,the testing accuracy is:- 0.4133140188386596
#
#
# At random state 18,the training accuracy is:- 0.357763065234986
# At random state 18,the testing accuracy is:- 0.3647496785769231
#
#
# At random state 19,the training accuracy is:- 0.3510677287438283
# At random state 19,the testing accuracy is:- 0.38502462179578545
#
#
# At random state 20,the training accuracy is:- 0.3653903983114474
# At random state 20,the testing accuracy is:- 0.33084092793076914
#
#
# At random state 21,the training accuracy is:- 0.35611831614753897
# At random state 21,the testing accuracy is:- 0.368455490037794
#
#
# At random state 22,the training accuracy is:- 0.36325899048460786
# At random state 22,the testing accuracy is:- 0.33049116554400504
#
#
# At random state 23,the training accuracy is:- 0.3440060273969866
# At random state 23,the testing accuracy is:- 0.42997879947313455
#
#
# At random state 24,the training accuracy is:- 0.3846703816734892
# At random state 24,the testing accuracy is:- 0.2544897487735076
#
#
# At random state 25,the training accuracy is:- 0.36900071550512825
# At random state 25,the testing accuracy is:- 0.3154516825962327
#
#
# At random state 26,the training accuracy is:- 0.3666343797141167
# At random state 26,the testing accuracy is:- 0.31353827469174644
#
#
# At random state 27,the training accuracy is:- 0.3433281278630894
# At random state 27,the testing accuracy is:- 0.4254015371788501
#
#
# At random state 28,the training accuracy is:- 0.35120933281344147
# At random state 28,the testing accuracy is:- 0.3827995635812004
#
#
# At random state 29,the training accuracy is:- 0.3499809929040809
# At random state 29,the testing accuracy is:- 0.38730125998501186
#
#
# At random state 30,the training accuracy is:- 0.3532840109859
# At random state 30,the testing accuracy is:- 0.38019825469950663
#
#
# At random state 31,the training accuracy is:- 0.36884135542739793
# At random state 31,the testing accuracy is:- 0.3172377940089769
#
#
# At random state 32,the training accuracy is:- 0.37152428347430955
# At random state 32,the testing accuracy is:- 0.29136997611173776
#
#
# At random state 33,the training accuracy is:- 0.35868847625822764
# At random state 33,the testing accuracy is:- 0.3613156788063786
#
#
# At random state 34,the training accuracy is:- 0.35524487468123256
# At random state 34,the testing accuracy is:- 0.37417466675946753
#
#
# At random state 35,the training accuracy is:- 0.36577743687761366
# At random state 35,the testing accuracy is:- 0.3275555176051729
#
#
# At random state 36,the training accuracy is:- 0.3609566215946577
# At random state 36,the testing accuracy is:- 0.3433691774019866
#
#
# At random state 37,the training accuracy is:- 0.35738594217158737
# At random state 37,the testing accuracy is:- 0.3635228272011135
#
#
# At random state 38,the training accuracy is:- 0.3572873532824701
# At random state 38,the testing accuracy is:- 0.3529411515773546
#
#
# At random state 39,the training accuracy is:- 0.34860803228354365
# At random state 39,the testing accuracy is:- 0.3924705803720212
#
#
# At random state 40,the training accuracy is:- 0.3435138143942261
# At random state 40,the testing accuracy is:- 0.4183385391256881
#
#
# At random state 41,the training accuracy is:- 0.3653350475531286
# At random state 41,the testing accuracy is:- 0.33436666740011967
#
#
# At random state 42,the training accuracy is:- 0.3479926193529862
# At random state 42,the testing accuracy is:- 0.40318034127962254
#
#
# At random state 43,the training accuracy is:- 0.3515161939299467
# At random state 43,the testing accuracy is:- 0.39005246019880013
#
#
# At random state 44,the training accuracy is:- 0.37025785726291227
# At random state 44,the testing accuracy is:- 0.3158293751197624
#
#
# At random state 45,the training accuracy is:- 0.3629610960698261
# At random state 45,the testing accuracy is:- 0.3354839153613193
#
#
# At random state 46,the training accuracy is:- 0.3713162022049451
# At random state 46,the testing accuracy is:- 0.317865809531258
#
#
# At random state 47,the training accuracy is:- 0.36413266141622747
# At random state 47,the testing accuracy is:- 0.3354925135221313
#
#
# At random state 48,the training accuracy is:- 0.3720270821776219
# At random state 48,the testing accuracy is:- 0.29845520574682194
#
#
# At random state 49,the training accuracy is:- 0.35370054748930757
# At random state 49,the testing accuracy is:- 0.38293188119502153
#
#
# At random state 50,the training accuracy is:- 0.36652697046943117
# At random state 50,the testing accuracy is:- 0.30560424818253984
#
#
# At random state 51,the training accuracy is:- 0.3795728703133
# At random state 51,the testing accuracy is:- 0.2757356716156796
#
#
# At random state 52,the training accuracy is:- 0.3604903320739691
# At random state 52,the testing accuracy is:- 0.35128445911514894
#
#
# At random state 53,the training accuracy is:- 0.351189419736311
# At random state 53,the testing accuracy is:- 0.38202985497990405
#
#
# At random state 54,the training accuracy is:- 0.36103858065341055
# At random state 54,the testing accuracy is:- 0.3414147932632777
#
#
# At random state 55,the training accuracy is:- 0.3582542991416646
# At random state 55,the testing accuracy is:- 0.3630450033159617
#
#
# At random state 56,the training accuracy is:- 0.35400079330975853
# At random state 56,the testing accuracy is:- 0.383869327420016
#
#
# At random state 57,the training accuracy is:- 0.3771453418988773
# At random state 57,the testing accuracy is:- 0.2931720025778374
#
#
# At random state 58,the training accuracy is:- 0.36219301198307774
# At random state 58,the testing accuracy is:- 0.34919806784601337
#
#
# At random state 59,the training accuracy is:- 0.37169222017916903
# At random state 59,the testing accuracy is:- 0.30251735492172505
#
#
# At random state 60,the training accuracy is:- 0.35294327722196783
# At random state 60,the testing accuracy is:- 0.3801116924746407
#
#
# At random state 61,the training accuracy is:- 0.34625646635467144
# At random state 61,the testing accuracy is:- 0.40698983950773615
#
#
# At random state 62,the training accuracy is:- 0.36416569171418545
# At random state 62,the testing accuracy is:- 0.33229650574370295
#
#
# At random state 63,the training accuracy is:- 0.35617735673316564
# At random state 63,the testing accuracy is:- 0.36902014792048965
#
#
# At random state 64,the training accuracy is:- 0.36959343690577917
# At random state 64,the testing accuracy is:- 0.31779369746795405
#
#
# At random state 65,the training accuracy is:- 0.35520470026811335
# At random state 65,the testing accuracy is:- 0.37637282221559343
#
#
# At random state 66,the training accuracy is:- 0.3764349940759879
# At random state 66,the testing accuracy is:- 0.2916574757885845
#
#
# At random state 67,the training accuracy is:- 0.366264831716239
# At random state 67,the testing accuracy is:- 0.32113413813504466
#
#
# At random state 68,the training accuracy is:- 0.37211988910054195
# At random state 68,the testing accuracy is:- 0.3010214835522558
#
#
# At random state 69,the training accuracy is:- 0.36427404583096334
# At random state 69,the testing accuracy is:- 0.34173472882639555
#
#
# At random state 70,the training accuracy is:- 0.36028100535262286
# At random state 70,the testing accuracy is:- 0.34984995328540747
#
#
# At random state 71,the training accuracy is:- 0.3544383311089542
# At random state 71,the testing accuracy is:- 0.3806694084902452
#
#
# At random state 72,the training accuracy is:- 0.3600656710016664
# At random state 72,the testing accuracy is:- 0.35945871846983635
#
#
# At random state 73,the training accuracy is:- 0.3658863607922094
# At random state 73,the testing accuracy is:- 0.32775241471450045
#
#
# At random state 74,the training accuracy is:- 0.3561013105362385
# At random state 74,the testing accuracy is:- 0.3719520834565053
#
#
# At random state 75,the training accuracy is:- 0.37783615734253706
# At random state 75,the testing accuracy is:- 0.2596786463727292
#
#
# At random state 76,the training accuracy is:- 0.36888236669033536
# At random state 76,the testing accuracy is:- 0.32217200912615773
#
#
# At random state 77,the training accuracy is:- 0.3611509097664817
# At random state 77,the testing accuracy is:- 0.3541885721580995
#
#
# At random state 78,the training accuracy is:- 0.35166768973908735
# At random state 78,the testing accuracy is:- 0.3844227553226759
#
#
# At random state 79,the training accuracy is:- 0.35705923156213837
# At random state 79,the testing accuracy is:- 0.35878206803716794
#
#
# At random state 80,the training accuracy is:- 0.3639118281132959
# At random state 80,the testing accuracy is:- 0.3333847344660137
#
#
# At random state 81,the training accuracy is:- 0.36135348599320505
# At random state 81,the testing accuracy is:- 0.35024993211259514
#
#
# At random state 82,the training accuracy is:- 0.35666415630935167
# At random state 82,the testing accuracy is:- 0.36490540366616486
#
#
# At random state 83,the training accuracy is:- 0.34913067520047625
# At random state 83,the testing accuracy is:- 0.4005571776632939
#
#
# At random state 84,the training accuracy is:- 0.3620414433812462
# At random state 84,the testing accuracy is:- 0.335165263235376
#
#
# At random state 85,the training accuracy is:- 0.36767167395121914
# At random state 85,the testing accuracy is:- 0.31041993433346804
#
#
# At random state 86,the training accuracy is:- 0.35625686325782013
# At random state 86,the testing accuracy is:- 0.3734605929460877
#
#
# At random state 87,the training accuracy is:- 0.39157816931526335
# At random state 87,the testing accuracy is:- 0.17669483642712047
#
#
# At random state 88,the training accuracy is:- 0.37276193600687824
# At random state 88,the testing accuracy is:- 0.3003845091941527
#
#
# At random state 89,the training accuracy is:- 0.35370210458416407
# At random state 89,the testing accuracy is:- 0.36922934860951795
#
#
# At random state 90,the training accuracy is:- 0.37110848565441357
# At random state 90,the testing accuracy is:- 0.3031150924017938
#
#
# At random state 91,the training accuracy is:- 0.3453001402081979
# At random state 91,the testing accuracy is:- 0.40646496313447944
#
#
# At random state 92,the training accuracy is:- 0.3433329199435283
# At random state 92,the testing accuracy is:- 0.43107092058070173
#
#
# At random state 93,the training accuracy is:- 0.351599579768607
# At random state 93,the testing accuracy is:- 0.38840707854320544
#
#
# At random state 94,the training accuracy is:- 0.38487397108661847
# At random state 94,the testing accuracy is:- 0.23864232422146658
#
#
# At random state 95,the training accuracy is:- 0.36606762257848047
# At random state 95,the testing accuracy is:- 0.3277184219067889
#
#
# At random state 96,the training accuracy is:- 0.3676095933128162
# At random state 96,the testing accuracy is:- 0.31778388745841046
#
#
# At random state 97,the training accuracy is:- 0.3740195705014856
# At random state 97,the testing accuracy is:- 0.2986738704058338
#
#
# At random state 98,the training accuracy is:- 0.3581109911243957
# At random state 98,the testing accuracy is:- 0.3607221915598965
#
#
# At random state 99,the training accuracy is:- 0.3657321664805212
# At random state 99,the testing accuracy is:- 0.3274135793301115

# %%
# train the model
lr.fit(features_train,target_train)
# Out:
# LinearRegression()

# %%
pred_test=lr.predict(features_test)

# %%
print(r2_score(target_test,pred_test))
# Out:
# 0.3274135793301115
